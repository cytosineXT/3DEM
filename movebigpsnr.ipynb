# %%
import os
import shutil
import re

# 源文件夹路径
source_folder = '/home/jiangxiaotian/workspace/3DEM/output/train/1013_puretrans_pretrain_conloss_0alpha/epoch40'

# 目标文件夹路径
destination_folder = '/home/jiangxiaotian/workspace/3DEM/output/train/1013_puretrans_pretrain_conloss_0alpha/bigpsnr'

# 如果目标文件夹不存在，创建它
os.makedirs(destination_folder, exist_ok=True)

# 正则表达式匹配 PSNR 值
psnr_pattern = re.compile(r'psnr(\d+\.\d+)')

# 遍历源文件夹中的文件
for filename in os.listdir(source_folder):
    # 匹配文件名中的 PSNR 值
    match = psnr_pattern.search(filename)
    if match:
        psnr_value = float(match.group(1))
        # 如果 PSNR 大于 20，复制文件到目标文件夹
        if psnr_value > 21.:
            source_file = os.path.join(source_folder, filename)
            destination_file = os.path.join(destination_folder, filename)
            shutil.copy(source_file, destination_file)
            print(f'Copied: {filename}')
            
            # 构建对应的 GT 文件名
            gt_filename = re.sub(r'psnr\d+\.\d+.*', '2DGT.png', filename)
            gt_source_file = os.path.join(source_folder, gt_filename)
            gt_destination_file = os.path.join(destination_folder, gt_filename)
            
            # 检查 GT 文件是否存在并复制
            if os.path.exists(gt_source_file):
                shutil.copy(gt_source_file, gt_destination_file)
                print(f'Copied: {gt_filename}')
# Out:
# Copied: epoch40_baa9_theta90phi210freq0.270_psnr23.19_ssim0.7667_mse0.0201_2D.png
# Copied: epoch40_baa9_theta90phi210freq0.270_2DGT.png
# Copied: epoch40_baa9_theta90phi90freq0.180_psnr21.04_ssim0.7604_mse0.0194_2D.png
# Copied: epoch40_baa9_theta90phi90freq0.180_2DGT.png
# Copied: epoch40_baa9_theta90phi300freq0.265_psnr23.38_ssim0.7495_mse0.0162_2D.png
# Copied: epoch40_baa9_theta90phi300freq0.265_2DGT.png
# Copied: epoch40_baa9_theta90phi150freq0.230_psnr21.35_ssim0.7467_mse0.0244_2D.png
# Copied: epoch40_baa9_theta90phi150freq0.230_2DGT.png
# Copied: epoch40_baa9_theta150phi210freq0.140_psnr23.38_ssim0.7623_mse0.0094_2D.png
# Copied: epoch40_baa9_theta150phi210freq0.140_2DGT.png
# Copied: epoch40_baa9_theta180phi270freq0.265_psnr21.96_ssim0.7666_mse0.0064_2D.png
# Copied: epoch40_baa9_theta180phi270freq0.265_2DGT.png
# Copied: epoch40_baa9_theta0phi120freq0.125_psnr22.86_ssim0.7269_mse0.0004_2D.png
# Copied: epoch40_baa9_theta0phi120freq0.125_2DGT.png
# Copied: epoch40_baa9_theta90phi300freq0.260_psnr22.68_ssim0.7368_mse0.0206_2D.png
# Copied: epoch40_baa9_theta90phi300freq0.260_2DGT.png
# Copied: epoch40_baa9_theta60phi210freq0.250_psnr22.53_ssim0.7743_mse0.0185_2D.png
# Copied: epoch40_baa9_theta60phi210freq0.250_2DGT.png
# Copied: epoch40_baa9_theta60phi210freq0.450_psnr22.67_ssim0.8003_mse0.0160_2D.png
# Copied: epoch40_baa9_theta60phi210freq0.450_2DGT.png
# Copied: epoch40_baa9_theta60phi150freq0.460_psnr21.98_ssim0.7934_mse0.0210_2D.png
# Copied: epoch40_baa9_theta60phi150freq0.460_2DGT.png
# Copied: epoch40_baa9_theta90phi90freq0.280_psnr21.06_ssim0.7876_mse0.0374_2D.png
# Copied: epoch40_baa9_theta90phi90freq0.280_2DGT.png
# Copied: epoch40_baa9_theta0phi270freq0.210_psnr21.22_ssim0.7742_mse0.0031_2D.png
# Copied: epoch40_baa9_theta0phi270freq0.210_2DGT.png
# Copied: epoch40_baa9_theta0phi90freq0.210_psnr22.30_ssim0.7879_mse0.0040_2D.png
# Copied: epoch40_baa9_theta0phi90freq0.210_2DGT.png
# Copied: epoch40_baa9_theta90phi150freq0.260_psnr21.32_ssim0.7373_mse0.0329_2D.png
# Copied: epoch40_baa9_theta90phi150freq0.260_2DGT.png
# Copied: epoch40_baa9_theta120phi150freq0.190_psnr21.76_ssim0.7653_mse0.0051_2D.png
# Copied: epoch40_baa9_theta120phi150freq0.190_2DGT.png
# Copied: epoch40_baa9_theta60phi300freq0.230_psnr21.33_ssim0.7755_mse0.0298_2D.png
# Copied: epoch40_baa9_theta60phi300freq0.230_2DGT.png
# Copied: epoch40_baa9_theta90phi60freq0.125_psnr21.26_ssim0.7398_mse0.0176_2D.png
# Copied: epoch40_baa9_theta90phi60freq0.125_2DGT.png
# Copied: epoch40_baa9_theta120phi270freq0.125_psnr21.27_ssim0.7633_mse0.0095_2D.png
# Copied: epoch40_baa9_theta120phi270freq0.125_2DGT.png
# Copied: epoch40_baa9_theta60phi30freq0.550_psnr21.20_ssim0.8060_mse0.0249_2D.png
# Copied: epoch40_baa9_theta60phi30freq0.550_2DGT.png
# Copied: epoch40_baa9_theta90phi60freq0.235_psnr21.96_ssim0.7630_mse0.0180_2D.png
# Copied: epoch40_baa9_theta90phi60freq0.235_2DGT.png
# Copied: epoch40_baa9_theta0phi90freq0.115_psnr21.15_ssim0.7401_mse0.0021_2D.png
# Copied: epoch40_baa9_theta0phi90freq0.115_2DGT.png
# Copied: epoch40_baa9_theta120phi330freq0.190_psnr21.65_ssim0.7935_mse0.0043_2D.png
# Copied: epoch40_baa9_theta120phi330freq0.190_2DGT.png
# Copied: epoch40_baa9_theta60phi210freq0.255_psnr22.00_ssim0.8005_mse0.0145_2D.png
# Copied: epoch40_baa9_theta60phi210freq0.255_2DGT.png
# Copied: epoch40_baa9_theta60phi210freq0.225_psnr23.71_ssim0.7975_mse0.0147_2D.png
# Copied: epoch40_baa9_theta60phi210freq0.225_2DGT.png
