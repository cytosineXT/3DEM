# %%
import os
import shutil
import re

# 源文件夹路径
source_folder = '/home/jiangxiaotian/workspace/3DEM/output/train/1021_puretrans_pretrain_conloss_fixmargin_0.0alpha/epoch59'

# 目标文件夹路径
destination_folder = '/home/jiangxiaotian/workspace/3DEM/output/train/1021_puretrans_pretrain_conloss_fixmargin_0.0alpha/bigpsnr60'

# 如果目标文件夹不存在，创建它
os.makedirs(destination_folder, exist_ok=True)

# 正则表达式匹配 PSNR 值
psnr_pattern = re.compile(r'psnr(\d+\.\d+)')

# 遍历源文件夹中的文件
for filename in os.listdir(source_folder):
    # 匹配文件名中的 PSNR 值
    match = psnr_pattern.search(filename)
    if match:
        psnr_value = float(match.group(1))
        # 如果 PSNR 大于 20，复制文件到目标文件夹
        if psnr_value > 23.:
            source_file = os.path.join(source_folder, filename)
            destination_file = os.path.join(destination_folder, filename)
            shutil.copy(source_file, destination_file)
            print(f'Copied: {filename}')
            
            # 构建对应的 GT 文件名
            gt_filename = re.sub(r'psnr\d+\.\d+.*', '2DGT.png', filename)
            gt_source_file = os.path.join(source_folder, gt_filename)
            gt_destination_file = os.path.join(destination_folder, gt_filename)
            
            # 检查 GT 文件是否存在并复制
            if os.path.exists(gt_source_file):
                shutil.copy(gt_source_file, gt_destination_file)
                print(f'Copied: {gt_filename}')
            
            # 构建对应的 cut 文件名
            cut_filename = re.sub(r'_2D.png', '_2Dcut.png', filename)
            cut_source_file = os.path.join(source_folder, cut_filename)
            cut_destination_file = os.path.join(destination_folder, cut_filename)
            
            # 检查 cut 文件是否存在并复制
            if os.path.exists(cut_source_file):
                shutil.copy(cut_source_file, cut_destination_file)
                print(f'Copied: {cut_filename}')
# Out:
# Copied: epoch59_baa9_theta90phi210freq0.270_psnr23.24_ssim0.7700_mse0.0277_2D.png
# Copied: epoch59_baa9_theta90phi210freq0.270_2DGT.png
# Copied: epoch59_baa9_theta90phi210freq0.270_psnr23.24_ssim0.7700_mse0.0277_2Dcut.png
# Copied: epoch59_baa9_theta0phi270freq0.210_psnr24.62_ssim0.8368_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta0phi270freq0.210_2DGT.png
# Copied: epoch59_baa9_theta0phi270freq0.210_psnr24.62_ssim0.8368_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta90phi210freq0.270_psnr23.24_ssim0.7700_mse0.0277_2Dcut.png
# Copied: epoch59_baa9_theta90phi210freq0.270_2DGT.png
# Copied: epoch59_baa9_theta90phi210freq0.270_psnr23.24_ssim0.7700_mse0.0277_2Dcut.png
# Copied: epoch59_baa9_theta30phi0freq0.120_psnr23.87_ssim0.7840_mse0.0031_2D.png
# Copied: epoch59_baa9_theta30phi0freq0.120_2DGT.png
# Copied: epoch59_baa9_theta30phi0freq0.120_psnr23.87_ssim0.7840_mse0.0031_2Dcut.png
# Copied: epoch59_baa9_theta30phi0freq0.120_psnr23.87_ssim0.7840_mse0.0031_2Dcut.png
# Copied: epoch59_baa9_theta30phi0freq0.120_2DGT.png
# Copied: epoch59_baa9_theta30phi0freq0.120_psnr23.87_ssim0.7840_mse0.0031_2Dcut.png
# Copied: epoch59_baa9_theta120phi210freq0.520_psnr23.14_ssim0.7866_mse0.0231_2D.png
# Copied: epoch59_baa9_theta120phi210freq0.520_2DGT.png
# Copied: epoch59_baa9_theta120phi210freq0.520_psnr23.14_ssim0.7866_mse0.0231_2Dcut.png
# Copied: epoch59_baa9_theta60phi150freq0.630_psnr24.32_ssim0.8009_mse0.0245_2Dcut.png
# Copied: epoch59_baa9_theta60phi150freq0.630_2DGT.png
# Copied: epoch59_baa9_theta60phi150freq0.630_psnr24.32_ssim0.8009_mse0.0245_2Dcut.png
# Copied: epoch59_baa9_theta0phi270freq0.210_psnr24.62_ssim0.8368_mse0.0016_2D.png
# Copied: epoch59_baa9_theta0phi270freq0.210_2DGT.png
# Copied: epoch59_baa9_theta0phi270freq0.210_psnr24.62_ssim0.8368_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta60phi210freq0.450_psnr23.95_ssim0.8016_mse0.0166_2Dcut.png
# Copied: epoch59_baa9_theta60phi210freq0.450_2DGT.png
# Copied: epoch59_baa9_theta60phi210freq0.450_psnr23.95_ssim0.8016_mse0.0166_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.500_psnr23.18_ssim0.7652_mse0.0192_2D.png
# Copied: epoch59_baa9_theta90phi150freq0.500_2DGT.png
# Copied: epoch59_baa9_theta90phi150freq0.500_psnr23.18_ssim0.7652_mse0.0192_2Dcut.png
# Copied: epoch59_baa9_theta0phi90freq0.210_psnr24.90_ssim0.8482_mse0.0016_2D.png
# Copied: epoch59_baa9_theta0phi90freq0.210_2DGT.png
# Copied: epoch59_baa9_theta0phi90freq0.210_psnr24.90_ssim0.8482_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta90phi210freq0.255_psnr23.31_ssim0.7825_mse0.0215_2D.png
# Copied: epoch59_baa9_theta90phi210freq0.255_2DGT.png
# Copied: epoch59_baa9_theta90phi210freq0.255_psnr23.31_ssim0.7825_mse0.0215_2Dcut.png
# Copied: epoch59_baa9_theta30phi330freq0.130_psnr23.37_ssim0.8564_mse0.0093_2Dcut.png
# Copied: epoch59_baa9_theta30phi330freq0.130_2DGT.png
# Copied: epoch59_baa9_theta30phi330freq0.130_psnr23.37_ssim0.8564_mse0.0093_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.295_psnr23.74_ssim0.7971_mse0.0264_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.295_2DGT.png
# Copied: epoch59_baa9_theta90phi150freq0.295_psnr23.74_ssim0.7971_mse0.0264_2Dcut.png
# Copied: epoch59_baa9_theta60phi210freq0.450_psnr23.95_ssim0.8016_mse0.0166_2D.png
# Copied: epoch59_baa9_theta60phi210freq0.450_2DGT.png
# Copied: epoch59_baa9_theta60phi210freq0.450_psnr23.95_ssim0.8016_mse0.0166_2Dcut.png
# Copied: epoch59_baa9_theta0phi90freq0.210_psnr24.90_ssim0.8482_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta0phi90freq0.210_2DGT.png
# Copied: epoch59_baa9_theta0phi90freq0.210_psnr24.90_ssim0.8482_mse0.0016_2Dcut.png
# Copied: epoch59_baa9_theta60phi150freq0.630_psnr24.32_ssim0.8009_mse0.0245_2D.png
# Copied: epoch59_baa9_theta60phi150freq0.630_2DGT.png
# Copied: epoch59_baa9_theta60phi150freq0.630_psnr24.32_ssim0.8009_mse0.0245_2Dcut.png
# Copied: epoch59_baa9_theta90phi210freq0.255_psnr23.31_ssim0.7825_mse0.0215_2Dcut.png
# Copied: epoch59_baa9_theta90phi210freq0.255_2DGT.png
# Copied: epoch59_baa9_theta90phi210freq0.255_psnr23.31_ssim0.7825_mse0.0215_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.500_psnr23.18_ssim0.7652_mse0.0192_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.500_2DGT.png
# Copied: epoch59_baa9_theta90phi150freq0.500_psnr23.18_ssim0.7652_mse0.0192_2Dcut.png
# Copied: epoch59_baa9_theta120phi210freq0.520_psnr23.14_ssim0.7866_mse0.0231_2Dcut.png
# Copied: epoch59_baa9_theta120phi210freq0.520_2DGT.png
# Copied: epoch59_baa9_theta120phi210freq0.520_psnr23.14_ssim0.7866_mse0.0231_2Dcut.png
# Copied: epoch59_baa9_theta30phi330freq0.130_psnr23.37_ssim0.8564_mse0.0093_2D.png
# Copied: epoch59_baa9_theta30phi330freq0.130_2DGT.png
# Copied: epoch59_baa9_theta30phi330freq0.130_psnr23.37_ssim0.8564_mse0.0093_2Dcut.png
# Copied: epoch59_baa9_theta90phi150freq0.295_psnr23.74_ssim0.7971_mse0.0264_2D.png
# Copied: epoch59_baa9_theta90phi150freq0.295_2DGT.png
# Copied: epoch59_baa9_theta90phi150freq0.295_psnr23.74_ssim0.7971_mse0.0264_2Dcut.png
