# %%
import os

# dest_folder = "/home/jiangxiaotian/workspace/3DEM"
dest_folder = "/home/jiangxiaotian/datasets/pbaa9_mie_train"

print(f"目标文件夹中的文件数量：{len(os.listdir(dest_folder))}")

total_size = 0
for root, dirs, files in os.walk(dest_folder):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        total_size += os.path.getsize(file_path)

total_size_mb = total_size / (1024 * 1024)  # 转换为 MB
total_size_gb = total_size / (1024 * 1024 * 1024)  # 转换为 GB

print(f"目标文件夹大小：{total_size_gb:.2f} GB")
# Out:
# 目标文件夹中的文件数量：7444
# 目标文件夹大小：9.91 GB

# %% [markdown]
# 2024.12.5 new单飞机allinone

# %%
import os
import shutil
import re
import time

#从train拷贝成pretrain
tic = time.time()

src_folder = "/home/jiangxiaotian/datasets/pbaa9_mie_train"
dest_folder = "/home/jiangxiaotian/datasets/mul2346_mie_50train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"
cnt = 3722 #抽出1/10做验证集
os.makedirs(dest_folder, exist_ok=True)

files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))
        # print(f)
        if f <= 1.0:
            src_file_path = os.path.join(src_folder, file_name)
            dest_file_path = os.path.join(dest_folder, file_name)
            shutil.copy(src_file_path, dest_file_path)
            cnt -= 1
    if cnt == 0:
        break

total_size = 0
for root, dirs, files in os.walk(dest_folder):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        total_size += os.path.getsize(file_path)

total_size_mb = total_size / (1024 * 1024)  # 转换为 MB
total_size_gb = total_size / (1024 * 1024 * 1024)  # 转换为 GB

print(f"目标文件夹中的文件数量：{len(os.listdir(dest_folder))}, {total_size_gb:.2f} GB")
print(f'耗时{(time.time()-tic):.4f}s')

tic = time.time()

src_folder = "/home/jiangxiaotian/datasets/pb979_mie_train"
dest_folder = "/home/jiangxiaotian/datasets/mul2346_mie_50train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"
cnt = 3722 #抽出1/10做验证集
os.makedirs(dest_folder, exist_ok=True)

files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))
        # print(f)
        if f <= 1.0:
            src_file_path = os.path.join(src_folder, file_name)
            dest_file_path = os.path.join(dest_folder, file_name)
            shutil.copy(src_file_path, dest_file_path)
            cnt -= 1
    if cnt == 0:
        break

total_size = 0
for root, dirs, files in os.walk(dest_folder):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        total_size += os.path.getsize(file_path)

total_size_mb = total_size / (1024 * 1024)  # 转换为 MB
total_size_gb = total_size / (1024 * 1024 * 1024)  # 转换为 GB

print(f"目标文件夹中的文件数量：{len(os.listdir(dest_folder))}, {total_size_gb:.2f} GB")
print(f'耗时{(time.time()-tic):.4f}s')

tic = time.time()

src_folder = "/home/jiangxiaotian/datasets/pb943_mie_train"
dest_folder = "/home/jiangxiaotian/datasets/mul2346_mie_50train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"
cnt = 3722 #抽出1/10做验证集
os.makedirs(dest_folder, exist_ok=True)

files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))
        # print(f)
        if f <= 1.0:
            src_file_path = os.path.join(src_folder, file_name)
            dest_file_path = os.path.join(dest_folder, file_name)
            shutil.copy(src_file_path, dest_file_path)
            cnt -= 1
    if cnt == 0:
        break

total_size = 0
for root, dirs, files in os.walk(dest_folder):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        total_size += os.path.getsize(file_path)

total_size_mb = total_size / (1024 * 1024)  # 转换为 MB
total_size_gb = total_size / (1024 * 1024 * 1024)  # 转换为 GB

print(f"目标文件夹中的文件数量：{len(os.listdir(dest_folder))}, {total_size_gb:.2f} GB")
print(f'耗时{(time.time()-tic):.4f}s')

tic = time.time()

src_folder = "/home/jiangxiaotian/datasets/pb7fd_mie_train"
dest_folder = "/home/jiangxiaotian/datasets/mul2346_mie_50train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"
cnt = 3722 #抽出1/10做验证集
os.makedirs(dest_folder, exist_ok=True)

files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))
        # print(f)
        if f <= 1.0:
            src_file_path = os.path.join(src_folder, file_name)
            dest_file_path = os.path.join(dest_folder, file_name)
            shutil.copy(src_file_path, dest_file_path)
            cnt -= 1
    if cnt == 0:
        break

total_size = 0
for root, dirs, files in os.walk(dest_folder):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        total_size += os.path.getsize(file_path)

total_size_mb = total_size / (1024 * 1024)  # 转换为 MB
total_size_gb = total_size / (1024 * 1024 * 1024)  # 转换为 GB

print(f"目标文件夹中的文件数量：{len(os.listdir(dest_folder))}, {total_size_gb:.2f} GB")
print(f'耗时{(time.time()-tic):.4f}s')
# Out:
# 目标文件夹中的文件数量：3722, 4.96 GB
# 耗时15.7000s
# 目标文件夹中的文件数量：7444, 9.93 GB
# 耗时15.4713s
# 目标文件夹中的文件数量：11166, 14.89 GB
# 耗时251.9560s
# 目标文件夹中的文件数量：14888, 19.85 GB
# 耗时123.3712s
