# %% [markdown]
# 单飞机单入射角随频率变化total RCS 2D图, 用mean就和CST的结果一样了，用sum的话趋势一样值不一样，说明没什么意义，用mean就行了。

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

frequencies = []
rcs_values = []

# Process files
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and theta == 90 and phi == 90:
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.mean().item()  # Assuming the tensor contains a single RCS value
            
            # Append frequency and RCS value to lists
            frequencies.append(f)
            rcs_values.append(rcs_value)

frequencies, rcs_values = zip(*sorted(zip(frequencies, rcs_values)))
# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(frequencies, rcs_values, marker='o', color='g')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xlim(0.09, 10)  # Set the x-axis range to 0-8
plt.title('RCS vs Frequency')
plt.xlabel('Frequency (GHz)')
plt.ylabel('mean RCS (m^2)')
plt.grid(True, which="both", ls="--")  # Add grid for better readability
plt.savefig(f'b943theta90phi90totalRCS1D.png')

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 1.73 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

frequencies = []
rcs_values = []

# Process files
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and theta == 90 and phi == 90:
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.sum().item()  # Assuming the tensor contains a single RCS value
            
            # Append frequency and RCS value to lists
            frequencies.append(f)
            rcs_values.append(rcs_value)

frequencies, rcs_values = zip(*sorted(zip(frequencies, rcs_values)))
# Plot the data
plt.figure(figsize=(5, 5))
plt.plot(frequencies, rcs_values, marker='o', color='g')
# plt.plot(frequencies, rcs_values, 'o', color='g')
# plt.plot(frequencies, rcs_values, 'o', linestyle='', color='g')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xlim(0.09, 10)  # Set the x-axis range to 0-8
plt.title('RCS vs Frequency')
plt.xlabel('Frequency (GHz)')
plt.ylabel('sum RCS (m^2)')
plt.grid(True, which="both", ls="--")  # Add grid for better readability
# plt.show()
plt.savefig('trysum.png')

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 13.95 seconds

# %% [markdown]
# 然后是同飞机不同入射角 画在同一张图里

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import time
import itertools

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

# Dictionary to store data for each (theta, phi) combination
data = {}

# Process files
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943':
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.mean().item()  # Assuming the tensor contains a single RCS value
            
            # Create key for (theta, phi) combination
            key = (theta, phi)
            if key not in data:
                data[key] = {'frequencies': [], 'rcs_values': []}
            
            # Append frequency and RCS value to lists
            data[key]['frequencies'].append(f)
            data[key]['rcs_values'].append(rcs_value)

# Plotting the data
plt.figure(figsize=(5, 5))
colors = itertools.cycle(plt.cm.tab20.colors)  # Cycle through 20 colors

for key, values in data.items():
    theta, phi = key
    frequencies, rcs_values = zip(*sorted(zip(values['frequencies'], values['rcs_values'])))
    plt.plot(frequencies, rcs_values, marker='o', linestyle='-', color=next(colors), label=f'theta={theta}, phi={phi}')

plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xlim(0.09, 10)  # Set the x-axis range
plt.title('RCS vs Frequency')
plt.xlabel('Frequency (GHz)')
plt.ylabel('mean RCS (m^2)')
plt.legend()  # Add legend to the plot
plt.grid(True, which="both", ls="--")  # Add grid for better readability
# plt.show()
plt.savefig('tryallinone.png')

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 382.47 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import time
import itertools

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

# Dictionary to store data for each (theta, phi) combination
data = {}

# Process files
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and theta == 90 and phi in [0,30,60,90,120,150,180,210]:
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.mean().item()  # Assuming the tensor contains a single RCS value
            
            # Create key for (theta, phi) combination
            key = (theta, phi)
            if key not in data:
                data[key] = {'frequencies': [], 'rcs_values': []}
            
            # Append frequency and RCS value to lists
            data[key]['frequencies'].append(f)
            data[key]['rcs_values'].append(rcs_value)

# Sort the data by (theta, phi) keys
sorted_data_keys = sorted(data.keys(), key=lambda x: (x[0], x[1]))

# Plotting the data
plt.figure(figsize=(10, 5))
colors = itertools.cycle(plt.cm.tab20.colors)  # Cycle through 20 colors

for key in sorted_data_keys:
    theta, phi = key
    values = data[key]
    frequencies, rcs_values = zip(*sorted(zip(values['frequencies'], values['rcs_values'])))
    plt.plot(frequencies, rcs_values, marker='o', linestyle='-', color=next(colors), label=f'theta={theta}, phi={phi}')

plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xlim(0.09, 10)  # Set the x-axis range
plt.title('RCS vs Frequency')
plt.xlabel('Frequency (GHz)')
plt.ylabel('mean RCS (m^2)')
plt.legend()  # Add legend to the plot
plt.grid(True, which="both", ls="--")  # Add grid for better readability
# plt.show()
plt.savefig('b943allinone_totalRCS1D.png')

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 11.12 seconds

# %% [markdown]
# 然后是同飞机同入射角 针对不同散射角的RCS随频率变化曲线 也就是某频率下平面360度的RCS，但是感觉是反向散射RCS？

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

rcs_matrix = np.zeros((181, 2))  # 行表示theta(0-180), 列表示phi(0, 180)

# Process files
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and theta in range(-1, 181) and (phi == 0 or phi == 180):
            rcs_value = torch.load(os.path.join(src_folder, file_name)).mean().item()
            rcs_matrix[theta, phi // 180] = rcs_value

# Plot the data
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
theta = np.linspace(0, 2 * np.pi, 181)
r = rcs_matrix[:, 0]
ax.plot(theta, r, color='g')
r = rcs_matrix[:, 1]
ax.plot(theta, r, color='b')
ax.set_rmax(max(np.max(rcs_matrix[:, 0]), np.max(rcs_matrix[:, 1])))
ax.set_title('RCS vs Angle (XOZ Plane)')
ax.set_xlabel('Angle (degrees)')
ax.set_ylabel('mean RCS (m^2)')
plt.savefig('try.png')

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 58.78 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.mean().item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 90)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(270 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270
# alpha_values_0 = np.deg2rad(np.array(theta_values) - 90)  # phi=0, theta 0-180 -> alpha -90 to 90
# alpha_values_180 = np.deg2rad(270 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 绘制极坐标图
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.plot(alpha_values, rcs_values, marker='o', linestyle='', color='g')

ax.set_title('RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")  # 添加网格线以便于阅读
plt.savefig('polar_plot_single_frequency.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.86 seconds

# %% [markdown]
# 单频点mean total RCS成功

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            rcs_value = tensor.mean().item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270
# alpha_values_0 = np.deg2rad(np.array(theta_values) - 90)  # phi=0, theta 0-180 -> alpha -90 to 90
# alpha_values_180 = np.deg2rad(270 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 绘制极坐标图
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.plot(alpha_values, rcs_values, marker='o', linestyle='', color='g')

ax.set_title('total RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")  # 添加网格线以便于阅读
plt.savefig('single_frequency_totalRCS.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.87 seconds

# %% [markdown]
# 单频点backscattered RCS成功

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2,phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270
# alpha_values_0 = np.deg2rad(np.array(theta_values) - 90)  # phi=0, theta 0-180 -> alpha -90 to 90
# alpha_values_180 = np.deg2rad(270 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 绘制极坐标图
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.plot(alpha_values, rcs_values, marker='o', linestyle='', color='g')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")  # 添加网格线以便于阅读
plt.savefig('single_frequency_backRCS.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.83 seconds

# %% [markdown]
# 单频点backscattered RCS 包络线成功

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2,phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 对 alpha_values 和 rcs_values 进行排序
sorted_idx = np.argsort(alpha_values)
sorted_alpha = alpha_values[sorted_idx]
sorted_rcs = rcs_values[sorted_idx]

# 在末尾添加第一个数据点,使曲线闭合
sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

# 绘制散点图和包围曲线
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.scatter(alpha_values, rcs_values, marker='o', color='g')
ax.plot(sorted_alpha, sorted_rcs, color='g', linestyle='-')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")
plt.savefig('singleF_backRCS_curve.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.84 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor.mean().item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 对 alpha_values 和 rcs_values 进行排序
sorted_idx = np.argsort(alpha_values)
sorted_alpha = alpha_values[sorted_idx]
sorted_rcs = rcs_values[sorted_idx]

# 在末尾添加第一个数据点,使曲线闭合
sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

# 绘制散点图和包围曲线
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.scatter(alpha_values, rcs_values, marker='o', color='g')
ax.plot(sorted_alpha, sorted_rcs, color='g', linestyle='-')

ax.set_title('total RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")
plt.savefig('singleF_totalRCS_curve.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.95 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and (f >= 0.1 and f <= 0.2) and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2, phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            if f not in data:
                data[f] = {}
            data[f][(theta, phi)] = rcs_value

colors = itertools.cycle(plt.cm.tab20.colors)  # 循环使用20种颜色

# 绘制图形
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')

for f, values in data.items():
    theta_values = sorted(set(theta for theta, phi in values.keys()))
    alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
    alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

    rcs_values_0 = [values[(theta, 0)] for theta in theta_values if (theta, 0) in values]
    rcs_values_180 = [values[(theta, 180)] for theta in theta_values if (theta, 180) in values]

    # 合并alpha和RCS值
    alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
    rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

    # 对 alpha_values 和 rcs_values 进行排序
    sorted_idx = np.argsort(alpha_values)
    sorted_alpha = alpha_values[sorted_idx]
    sorted_rcs = rcs_values[sorted_idx]

    # 在末尾添加第一个数据点,使曲线闭合
    sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
    sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

    # 绘制散点图和包围曲线
    color = next(colors)
    ax.scatter(alpha_values, rcs_values, marker='o', color=color)
    ax.plot(sorted_alpha, sorted_rcs, color=color, linestyle='-', label=f'f = {f} GHz')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (0.1-1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5), title='Frequencies')
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve_multi_frequenciesthetaphi.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 3.24 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and (f >= 0.1 and f <= 1) and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2, :].mean().item()  # 取theta对应行的平均值
            
            # 合并phi=0 和 phi=180 的数据
            alpha = np.deg2rad(360 - theta) if phi == 180 else np.deg2rad(theta)
            
            if f not in data:
                data[f] = {}
            data[f][alpha] = rcs_value

colors = itertools.cycle(plt.cm.tab20.colors)  # 循环使用20种颜色

# 绘制图形
plt.figure(figsize=(10, 10))
ax = plt.subplot(111, projection='polar')

for f, values in data.items():
    alpha_values = sorted(values.keys())
    rcs_values = [values[alpha] for alpha in alpha_values]

    # 在末尾添加第一个数据点,使曲线闭合
    alpha_values = np.concatenate((alpha_values, [alpha_values[0]]))
    rcs_values = np.concatenate((rcs_values, [rcs_values[0]]))

    # 绘制散点图和包围曲线
    color = next(colors)
    ax.scatter(alpha_values, rcs_values, marker='o', color=color)
    ax.plot(alpha_values, rcs_values, color=color, linestyle='-', label=f'f = {f:.1f} GHz')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (0.1-1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5), title='Frequencies')
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve_multi_frequenciesalpha.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 14.21 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and (f >= 0.1 and f <= 0.2) and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2, phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            if f not in data:
                data[f] = {}
            data[f][(theta, phi)] = rcs_value

# 对f值从小到大排序
sorted_data = sorted(data.items(), key=lambda x: x[0])

colors = itertools.cycle(plt.cm.tab20.colors)  # 循环使用20种颜色

# 绘制图形
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')

for f, values in sorted_data:
    theta_values = sorted(set(theta for theta, phi in values.keys()))
    alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
    alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

    rcs_values_0 = [values[(theta, 0)] for theta in theta_values if (theta, 0) in values]
    rcs_values_180 = [values[(theta, 180)] for theta in theta_values if (theta, 180) in values]

    # 合并alpha和RCS值
    alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
    rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

    # 对 alpha_values 和 rcs_values 进行排序
    sorted_idx = np.argsort(alpha_values)
    sorted_alpha = alpha_values[sorted_idx]
    sorted_rcs = rcs_values[sorted_idx]

    # 在末尾添加第一个数据点,使曲线闭合
    sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
    sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

    # 绘制散点图和包围曲线
    color = next(colors)
    ax.scatter(alpha_values, rcs_values, marker='o', color=color)
    ax.plot(sorted_alpha, sorted_rcs, color=color, linestyle='-', label=f'f = {f} GHz')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (0.1-0.2 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5), title='Frequencies')
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve_multi_frequenciesthetaphi.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 3.77 seconds

# %% [markdown]
# 不同频率total RCS xoz平面2D曲线

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and (f >= 0.1 and f <= 0.2) and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor.mean().item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            if f not in data:
                data[f] = {}
            data[f][(theta, phi)] = rcs_value

# 对f值从小到大排序
sorted_data = sorted(data.items(), key=lambda x: x[0])

colors = itertools.cycle(plt.cm.tab20.colors)  # 循环使用20种颜色

# 绘制图形
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')

for f, values in sorted_data:
    theta_values = sorted(set(theta for theta, phi in values.keys()))
    alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
    alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

    rcs_values_0 = [values[(theta, 0)] for theta in theta_values if (theta, 0) in values]
    rcs_values_180 = [values[(theta, 180)] for theta in theta_values if (theta, 180) in values]

    # 合并alpha和RCS值
    alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
    rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

    # 对 alpha_values 和 rcs_values 进行排序
    sorted_idx = np.argsort(alpha_values)
    sorted_alpha = alpha_values[sorted_idx]
    sorted_rcs = rcs_values[sorted_idx]

    # 在末尾添加第一个数据点,使曲线闭合
    sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
    sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

    # 绘制散点图和包围曲线
    color = next(colors)
    ax.scatter(alpha_values, rcs_values, marker='o', color=color)
    ax.plot(sorted_alpha, sorted_rcs, color=color, linestyle='-', label=f'f = {f} GHz')

ax.set_title('total RCS in XoZ plane vs Alpha (0.1-0.2 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5), title='Frequencies')
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve_multi_frequenciesthetaphi.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 3.05 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and (f >= 0.1 and f <= 0.15) and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor.mean().item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            if f not in data:
                data[f] = {}
            data[f][(theta, phi)] = rcs_value

# 对f值从小到大排序
sorted_data = sorted(data.items(), key=lambda x: x[0])

colors = itertools.cycle(plt.cm.tab20.colors)  # 循环使用20种颜色

# 绘制图形
plt.figure(figsize=(8, 5))
# plt.figure()
ax = plt.subplot(111, projection='polar')

for f, values in sorted_data:
    theta_values = sorted(set(theta for theta, phi in values.keys()))
    alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
    alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

    rcs_values_0 = [values[(theta, 0)] for theta in theta_values if (theta, 0) in values]
    rcs_values_180 = [values[(theta, 180)] for theta in theta_values if (theta, 180) in values]

    # 合并alpha和RCS值
    alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
    rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

    # 对 alpha_values 和 rcs_values 进行排序
    sorted_idx = np.argsort(alpha_values)
    sorted_alpha = alpha_values[sorted_idx]
    sorted_rcs = rcs_values[sorted_idx]

    # 在末尾添加第一个数据点,使曲线闭合
    sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
    sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

    # 绘制散点图和包围曲线
    color = next(colors)
    ax.scatter(alpha_values, rcs_values, marker='o', color=color)
    ax.plot(sorted_alpha, sorted_rcs, color=color, linestyle='-', label=f'f = {f} GHz')

ax.set_title('total RCS in XoZ plane vs Alpha (0.1-0.15 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5), title='Frequencies')
plt.grid(True, which="both", ls="--")
plt.savefig('mul0.1-0.15GF_totalRCS.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 2.17 seconds

# %% [markdown]
# 单频点带推理0.2° backscattered RCS 2D图？

# %% [markdown]
# ![alt text](ref/polar_plot_with_curve.png)

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2,phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 对 alpha_values 和 rcs_values 进行排序
sorted_idx = np.argsort(alpha_values)
sorted_alpha = alpha_values[sorted_idx]
sorted_rcs = rcs_values[sorted_idx]

# 在末尾添加第一个数据点,使曲线闭合
sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

# 绘制散点图和包围曲线
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.scatter(alpha_values, rcs_values, marker='o', color='g')
ax.plot(sorted_alpha, sorted_rcs, color='g', linestyle='-')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 0.82 seconds

# %%
import os
import re
import torch
import matplotlib.pyplot as plt
import numpy as np
import time

tic = time.time()

src_folder = "/mnt/Disk/jiangxiaotian/puredatasets/mul2347_train"
pattern = r"([a-zA-Z0-9]{4})_theta(\d+)phi(\d+)f(\d+\.\d+).pt"

data = {}

# 读取文件并筛选数据
files = os.listdir(src_folder)
for file_name in files:
    match = re.match(pattern, file_name)
    if match:
        plane = match.group(1)
        theta = int(match.group(2))
        phi = int(match.group(3))
        f = float(match.group(4))

        if plane == 'b943' and f == 0.1 and (phi == 0 or phi == 180):
            src_file_path = os.path.join(src_folder, file_name)
            tensor = torch.load(src_file_path)
            tensor[:, 0][tensor[:, 0] == 0] = tensor[:, -1][tensor[:, 0] == 0]
            rcs_value = tensor[theta*2,phi*2].item()  # 假设张量包含一个单一的RCS值

            # 存储数据
            key = (theta, phi)
            data[key] = rcs_value

# 转换数据格式用于绘图
theta_values = sorted(set(theta for theta, phi in data.keys()))
alpha_values_0 = np.deg2rad(np.array(theta_values) - 0)  # phi=0, theta 0-180 -> alpha -90 to 90
alpha_values_180 = np.deg2rad(360 - np.array(theta_values))  # phi=180, theta 0-180 -> alpha 90 to 270

rcs_values_0 = [data[(theta, 0)] for theta in theta_values if (theta, 0) in data]
rcs_values_180 = [data[(theta, 180)] for theta in theta_values if (theta, 180) in data]

# 合并alpha和RCS值
alpha_values = np.concatenate((alpha_values_0, alpha_values_180))
rcs_values = np.concatenate((rcs_values_0, rcs_values_180))

# 对 alpha_values 和 rcs_values 进行排序
sorted_idx = np.argsort(alpha_values)
sorted_alpha = alpha_values[sorted_idx]
sorted_rcs = rcs_values[sorted_idx]

# 在末尾添加第一个数据点,使曲线闭合
sorted_alpha = np.concatenate((sorted_alpha, [sorted_alpha[0]]))
sorted_rcs = np.concatenate((sorted_rcs, [sorted_rcs[0]]))

# 绘制散点图和包围曲线
plt.figure(figsize=(5, 5))
ax = plt.subplot(111, projection='polar')
ax.scatter(alpha_values, rcs_values, marker='o', color='g')
ax.plot(sorted_alpha, sorted_rcs, color='g', linestyle='-')

ax.set_title('BackScattered RCS in XoZ plane vs Alpha (f = 0.1 GHz)')
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
plt.grid(True, which="both", ls="--")
plt.savefig('polar_plot_with_curve.png')
plt.show()

toc = time.time()
print(f"Time taken: {toc - tic:.2f} seconds")
# Out:
# Time taken: 1.34 seconds
